# %% [markdown]
# # Spoofing Detection for Maritime AIS Data

# %%
# Environment setup and imports
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'  # Fix OpenMP conflict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Deep Learning - PyTorch
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F

# Sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report

# Visualization
import folium
from folium import plugins
import itertools

print(f"PyTorch version: {torch.__version__}")
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"GPU Device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")
print(f"Numpy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
print("All packages loaded successfully")

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.9.1+cu126
# GPU Available: True
# GPU Device: NVIDIA GeForce RTX 4060 Laptop GPU
# Numpy version: 1.26.4
# Pandas version: 2.3.3
# All packages loaded successfully
# Using device: cuda

# %% [markdown]
# ## 1. Data Loading & Preprocessing
#
# Load AIS data from incident slices created in the incident analysis notebook.

# %%
# Configuration
data_root = Path("../dataset/piraeus")
output_root = Path("./models")
output_root.mkdir(parents=True, exist_ok=True)

# AIS dataset configuration (from incident_anomaly_labels.ipynb)
cols_primary = ["timestamp", "vessel_id", "lon", "lat", "speed", "course", "heading"]
cols_alias = ["t", "timestamp", "vessel_id", "lon", "lat", "speed", "course", "heading"]

MONTH_ABBR = {
    1: "jan", 2: "feb", 3: "mar", 4: "apr", 5: "may", 6: "jun",
    7: "jul", 8: "aug", 9: "sep", 10: "oct", 11: "nov", 12: "dec"
}

# Years and months to load for comprehensive training
DATA_PERIODS = [
    (2017, [5, 6, 7, 8, 9, 10, 11, 12]),  # May-Dec 2017
    (2018, list(range(1, 13))),            # Full year 2018
    (2019, list(range(1, 13))),            # Full year 2019
]

print("Configuration loaded")
print(f"Data root: {data_root}")
print(f"Loading periods: 2017-2019 (multiple months)")
# Out:
# Configuration loaded
# Data root: ..\dataset\piraeus
# Loading periods: 2017-2019 (multiple months)

# %%
def load_month(year, month, root, chunk_size=500_000):
    """Load AIS data for a specific month (from incident_anomaly_labels.ipynb)."""
    folder = Path(root) / f"unipi_ais_dynamic_{year}"
    fname = folder / f"unipi_ais_dynamic_{MONTH_ABBR[month]}{year}.csv"
    if not fname.exists():
        raise FileNotFoundError(f"Missing file: {fname}")

    # Discover available columns
    preview = pd.read_csv(fname, nrows=1)
    available = list(preview.columns)
    selected_cols = [c for c in cols_alias if c in available]
    print(f"Selected columns: {selected_cols}")
    
sample_months=12
for year, months in DATA_PERIODS:
    # Sample subset of months to manage memory
    selected_months = np.random.choice(months, min(sample_months, len(months)), replace=False)
    
    for i, month in enumerate(selected_months):
        print(f"{i+1} Loading {year}-{month:02d}...")
        load_month(year, month, data_root)
# Out:
# 1 Loading 2017-06...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 2 Loading 2017-10...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 3 Loading 2017-05...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 4 Loading 2017-11...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 5 Loading 2017-12...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 6 Loading 2017-07...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 7 Loading 2017-08...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 8 Loading 2017-09...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 1 Loading 2018-04...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 2 Loading 2018-11...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 3 Loading 2018-08...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 4 Loading 2018-12...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 5 Loading 2018-06...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 6 Loading 2018-07...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 7 Loading 2018-02...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 8 Loading 2018-09...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 9 Loading 2018-05...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 10 Loading 2018-03...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 11 Loading 2018-01...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 12 Loading 2018-10...
# Selected columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 1 Loading 2019-09...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 2 Loading 2019-01...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 3 Loading 2019-05...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 4 Loading 2019-11...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 5 Loading 2019-03...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 6 Loading 2019-12...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 7 Loading 2019-06...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 8 Loading 2019-08...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 9 Loading 2019-10...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 10 Loading 2019-07...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 11 Loading 2019-04...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']
# 12 Loading 2019-02...
# Selected columns: ['t', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']

# %% [markdown]
# Since we have t and timestamp variation, column_primary and col_alias are used

# %%
# Load AIS data from full dataset
def load_month(year, month, root, chunk_size=500_000):
    """Load AIS data for a specific month (from incident_anomaly_labels.ipynb)."""
    folder = Path(root) / f"unipi_ais_dynamic_{year}"
    fname = folder / f"unipi_ais_dynamic_{MONTH_ABBR[month]}{year}.csv"
    if not fname.exists():
        raise FileNotFoundError(f"Missing file: {fname}")

    # Discover available columns
    preview = pd.read_csv(fname, nrows=1)
    available = list(preview.columns)
    selected_cols = [c for c in cols_alias if c in available]

    chunks = []
    for chunk in pd.read_csv(fname, usecols=selected_cols, chunksize=chunk_size):
        if "t" in chunk.columns and "timestamp" not in chunk.columns:
            chunk = chunk.rename(columns={"t": "timestamp"})
        chunk["timestamp"] = pd.to_datetime(chunk["timestamp"], unit="ms", utc=True)
        chunk = chunk[[c for c in cols_primary if c in chunk.columns]]
        chunks.append(chunk)
    return pd.concat(chunks, ignore_index=True)


def load_ais_dataset(data_periods, root, sample_months=3):
    """Load multiple months of AIS data for training."""
    all_data = []
    loaded_count = 0

    for year, months in data_periods:
        # Sample subset of months to manage memory
        selected_months = np.random.choice(months, min(sample_months, len(months)), replace=False)
        
        for month in selected_months:
            try:
                print(f"Loading {year}-{month:02d}...")
                df = load_month(year, month, root)
                all_data.append(df)
                loaded_count += 1
                print(f"  Loaded: {len(df):,} records, {df['vessel_id'].nunique()} vessels")
            except FileNotFoundError as e:
                print(f"  Skipped: {e}")
                continue
            except Exception as e:
                print(f"  Error: {e}")
                continue
    
    if not all_data:
        raise FileNotFoundError("No AIS data found. Check data_root path.")
    
    combined_df = pd.concat(all_data, ignore_index=True)
    print(f"\nTotal months loaded: {loaded_count}")
    return combined_df


# Load data (sample 3 months per year for manageable dataset size)
print("Loading AIS dataset...")
ais_data = load_ais_dataset(DATA_PERIODS, data_root, sample_months=3)

print(f"\nDataset Summary:")
print(f"  Total records: {len(ais_data):,}")
print(f"  Unique vessels: {ais_data['vessel_id'].nunique()}")
print(f"  Time range: {ais_data['timestamp'].min()} to {ais_data['timestamp'].max()}")
print(f"  Columns: {list(ais_data.columns)}")
# Out:
# Loading AIS dataset...
# Loading 2017-10...
#   Loaded: 4,286,717 records, 816 vessels
# Loading 2017-09...
#   Loaded: 7,622,161 records, 1135 vessels
# Loading 2017-06...
#   Loaded: 8,107,297 records, 1119 vessels
# Loading 2018-03...
#   Loaded: 6,338,935 records, 795 vessels
# Loading 2018-01...
#   Loaded: 5,458,182 records, 659 vessels
# Loading 2018-07...
#   Loaded: 13,813,130 records, 1344 vessels
# Loading 2019-02...
#   Loaded: 6,930,667 records, 874 vessels
# Loading 2019-05...
#   Loaded: 7,015,268 records, 1175 vessels
# Loading 2019-04...
#   Loaded: 7,139,650 records, 1055 vessels
#
# Total months loaded: 9
#
# Dataset Summary:
#   Total records: 66,712,007
#   Unique vessels: 4159
#   Time range: 2017-05-31 21:00:00+00:00 to 2019-05-30 20:59:59+00:00
#   Columns: ['timestamp', 'vessel_id', 'lon', 'lat', 'speed', 'course', 'heading']

# %%
def ais_month_generator(year, month, root, chunk_size=500_000):
    folder = Path(root) / f"unipi_ais_dynamic_{year}"
    fname = folder / f"unipi_ais_dynamic_{MONTH_ABBR[month]}{year}.csv"

    preview = pd.read_csv(fname, nrows=1)
    selected_cols = [c for c in cols_alias if c in preview.columns]

    for chunk in pd.read_csv(fname, usecols=selected_cols, chunksize=chunk_size):
        if "t" in chunk.columns and "timestamp" not in chunk.columns:
            chunk = chunk.rename(columns={"t": "timestamp"})
        chunk["timestamp"] = pd.to_datetime(chunk["timestamp"], unit="ms", utc=True)
        chunk = chunk[[c for c in cols_primary if c in chunk.columns]]
        yield chunk

# %%
import torch
from torch.utils.data import IterableDataset, DataLoader
from tqdm import tqdm
import numpy as np

class AISDataset(IterableDataset):
    def __init__(self, data_periods, root, window_size=128):
        """
        Iterable dataset for AIS data sliding windows.

        Returns: (window_tensor, vessel_id)
        window_tensor shape: (window_size, 5) -> [lat, lon, speed, course, timestamp]
        vessel_id: string
        """
        self.data_periods = data_periods
        self.root = root
        self.window_size = window_size

    def __iter__(self):
        for year, months in self.data_periods:
            for month in months:
                for chunk in ais_month_generator(year, month, self.root):
                    for vessel_id, df_v in chunk.groupby("vessel_id"):
                        df_v = df_v.sort_values("timestamp")

                        # Extract numeric features
                        values = df_v[["lat", "lon", "speed", "course"]].values.astype(np.float32)

                        # Convert timestamps to float seconds
                        timestamps = (df_v["timestamp"].astype("int64") // 10**9).values.astype(np.float32)
                        timestamps = timestamps.reshape(-1, 1)

                        # Combine into sliding window array
                        window_data = np.hstack([values, timestamps])

                        # Yield sliding windows along with vessel_id
                        for i in range(len(window_data) - self.window_size):
                            yield torch.tensor(window_data[i:i+self.window_size], dtype=torch.float32), vessel_id

# Loader
loader = DataLoader(
    AISDataset(DATA_PERIODS, data_root, window_size=128),
    batch_size=64,        # number of windows per batch
    num_workers=0         # single-threaded safe for IterableDataset
)

# %% [markdown]
# Temporal coverage
#
# Each “window” covers 128 consecutive AIS messages for a vessel.
#
# If AIS messages are sent, say, every 1–2 minutes, then 128 messages ≈ 2–4 hours of movement.
#
# If anomalies occur over longer time periods (e.g., abnormal route over a day), 128 may be too short.

# %%
# Columns in window tensor
check_cols = ["lat", "lon", "speed", "course", "timestamp"]

# Stats holders
missing_counts = {c: 0 for c in check_cols}
speed_violations = 0
course_violations = 0
duplicate_timestamps = 0
negative_time_diff = 0
stationary_vessels = set()
total_windows = 0

# Iterate through loader
for batch, vessel_ids in tqdm(loader, desc="Checking raw AIS data"):
    # batch shape: (batch_size, window_size, features)
    batch = batch.cpu()
    batch_size, window_size, n_features = batch.shape
    total_windows += batch_size

    # Check NaNs
    for i, col in enumerate(check_cols):
        missing_counts[col] += torch.isnan(batch[:, :, i]).sum().item()

    # Speed violations (>100 or <0)
    speed_idx = check_cols.index("speed")
    speed_violations += ((batch[:, :, speed_idx] > 100) |
                         (batch[:, :, speed_idx] < 0)).sum().item()

    # Course violations (>360 or <0)
    course_idx = check_cols.index("course")
    course_violations += ((batch[:, :, course_idx] > 360) |
                          (batch[:, :, course_idx] < 0)).sum().item()

    # Time differences and duplicates
    ts_idx = check_cols.index("timestamp")
    for b in range(batch_size):
        dt = batch[b, 1:, ts_idx] - batch[b, :-1, ts_idx]
        negative_time_diff += (dt < 0).sum().item()
        duplicate_timestamps += (dt == 0).sum().item()

        # Stationary vessel check (<0.5 knots)
        if (batch[b, :, speed_idx] < 0.5).all():
            stationary_vessels.add(vessel_ids[b])

# Print summary
print("\n=== Pre-Cleaning AIS Data Summary ===")
print(f"Total windows processed: {total_windows:,}")
for col in check_cols:
    print(f"Missing values in {col}: {missing_counts[col]}")
print(f"Speed violations (>100 or <0 knots): {speed_violations}")
print(f"Course violations (>360 or <0 degrees): {course_violations}")
print(f"Duplicate timestamps: {duplicate_timestamps}")
print(f"Negative time differences: {negative_time_diff}")
print(f"Stationary vessels detected: {len(stationary_vessels)}")
# Out:
# Checking raw AIS data: 301474it [43:29, 115.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 32
#      29 # Course violations (>360 or <0)
#      30 course_idx = check_cols.index("course")
#      31 course_violations += ((batch[:, :, course_idx] > 360) |
# ---> 32                       (batch[:, :, course_idx] < 0)).sum().item()
#      34 # Time differences and duplicates
#      35 ts_idx = check_cols.index("timestamp")
#
# KeyboardInterrupt:

# %% [markdown]
# KeyboardInterrupt: was performed as we had already checked a substantial amount of records close to 19 M records which 9 percent subset of the data.

# %%
print("\n=== Pre-Cleaning AIS Data Summary ===")
print(f"Total windows processed: {total_windows:,}")
for col in check_cols:
    print(f"Missing values in {col}: {missing_counts[col]}")
print(f"Speed violations (>100 or <0 knots): {speed_violations}")
print(f"Course violations (>360 or <0 degrees): {course_violations}")
print(f"Duplicate timestamps: {duplicate_timestamps}")
print(f"Negative time differences: {negative_time_diff}")
print(f"Stationary vessels detected: {len(stationary_vessels)}")
# Out:
# === Pre-Cleaning AIS Data Summary ===
# Total windows processed: 19,294,400
# Missing values in lat: 0
# Missing values in lon: 0
# Missing values in speed: 13913925
# Missing values in course: 251599680
# Missing values in timestamp: 0
# Speed violations (>100 or <0 knots): 97400
# Course violations (>360 or <0 degrees): 0
# Duplicate timestamps: 2018963744
# Negative time differences: 0
# Stationary vessels detected: 975

# %%
for batch in loader:
    batch = batch.to(device)
    print(batch.shape)
    break
    # loss = model(batch)
    # loss.backward()
# Out:
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1002 records
# Vessel 00f122d09f0a9d8c26eb19e9abcd6ba3463df344117f5631d33ecf1b2e34f94f has 351 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 598 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 853 records
# Vessel 00f122d09f0a9d8c26eb19e9abcd6ba3463df344117f5631d33ecf1b2e34f94f has 353 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 212 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 441 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 422 records
# Vessel 00c7725d1ff8ff36fc4091b1aef03261fb1a9e38b11f20d5604fb5607a94a4f2 has 1 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 763 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 857 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 277 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 72 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 986 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 158 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 875 records
# Vessel 001680b0d55b053ae6558a0ce257e717dfd188fd98e6c2cd3b5d4db5c7ae5a63 has 677 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1006 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 82 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1273 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 75 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 277 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 72 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 2 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 554 records
# Vessel 02dfaf1649779c256e806c80b4891674b7b1c20c5dc7bde959dbedb30c9a263c has 165 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 481 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 20 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 904 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2005 records
# Vessel 00f122d09f0a9d8c26eb19e9abcd6ba3463df344117f5631d33ecf1b2e34f94f has 1418 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 595 records
# Vessel 03a2a8913bf23f6a3cf945d2f06a56f3923eb2ff53165914e01a9e36dbfec5d1 has 1086 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 270 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 576 records
# Vessel 01be895590c493e82ecfabdb73b9e881e0f2335a19e96091418d029697ec8b00 has 1571 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 707 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 508 records
# Vessel 0029e98942959ce856264edc44b0761585fb8b738cb7f6ee34c404b2dec24c4e has 75 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 904 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 411 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 141 records
# Vessel 0029e98942959ce856264edc44b0761585fb8b738cb7f6ee34c404b2dec24c4e has 40 records
# Vessel 02ee8d3076e26b0f9d2ac86aefafcefa62887577f73e17e7a468c81aa5839247 has 1852 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2436 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 746 records
# Vessel 007a509a904b141cb86a36830c32b6ad9b02fccfcd3ac9b10bbb8dd2957b1834 has 77 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 178 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 898 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 110 records
# Vessel 007a509a904b141cb86a36830c32b6ad9b02fccfcd3ac9b10bbb8dd2957b1834 has 262 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 183 records
# Vessel 026a5361847ec9d1b35335eb67fd73b4bc0178126e8be7844ed6e8e8a4c0573b has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 572 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 684 records
# Vessel 00dbb7ebcf10dab5aeb361f837867da69b1a60895e736290460416a51ff2b3bf has 269 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1046 records
# Vessel 00dbb7ebcf10dab5aeb361f837867da69b1a60895e736290460416a51ff2b3bf has 536 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 600 records
# Vessel 04b6c84a518f833b7206a114ada7660d56888de1af6cabc7bbe2c46ea6a7d733 has 19 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2735 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 410 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 170 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 117 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 208 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 53 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 351 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 180 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 818 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 17 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 67 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 139 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 24 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 27 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 27 records
# Vessel 0005115c6a9a25cc995ef74ddd285c52001cba5a9c298acffccf5deee572aa27 has 16 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 723 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 428 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 405 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 455 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 588 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 272 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 63 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 588 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 588 records
# Vessel 00f8b3a5c8b93bccb62f2b52f8e274194267a4eec4a3dad435cc67756628dead has 454 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 500 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2289 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 287 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1033 records
# Vessel 00f8b3a5c8b93bccb62f2b52f8e274194267a4eec4a3dad435cc67756628dead has 445 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 541 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2586 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 292 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 268 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 288 records
# Vessel 02ee8d3076e26b0f9d2ac86aefafcefa62887577f73e17e7a468c81aa5839247 has 451 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 278 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 732 records
# Vessel 02dfaf1649779c256e806c80b4891674b7b1c20c5dc7bde959dbedb30c9a263c has 143 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1428 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 314 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 612 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2088 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 371 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 13 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 568 records
# Vessel 02dfaf1649779c256e806c80b4891674b7b1c20c5dc7bde959dbedb30c9a263c has 336 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1509 records
# Vessel 00247f5f598eabbbc9062d8b6e91be04e24ed20418bec490f6beb7047f0004e4 has 79 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 904 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 398 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 73 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 315 records
# Vessel 00247f5f598eabbbc9062d8b6e91be04e24ed20418bec490f6beb7047f0004e4 has 79 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 1056 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 398 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 66 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 322 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 412 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 7 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 935 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 271 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1308 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 370 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 397 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 401 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 805 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 8 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1635 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 322 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 288 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 420 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 303 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 27 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 480 records
# Vessel 00a0b89496265007770715da9b3406889de26ab6f5ada21c3ae9cf16f6cbd41d has 3 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 718 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 288 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 420 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 303 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 27 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 507 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 480 records
# Vessel 0086b93a1666c0aa2876c335227a87b4e7e046a865502e712d23ffb2ed7bd88e has 258 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 755 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 91 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 624 records
# Vessel 025dc2bc6e81fdd02b3deeb1e98ad62fce09c26abe98a01b661a997a1e67f40e has 7822 records
# Vessel 025dc2bc6e81fdd02b3deeb1e98ad62fce09c26abe98a01b661a997a1e67f40e has 1417 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1433 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 42 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 346 records
# Vessel 0086b93a1666c0aa2876c335227a87b4e7e046a865502e712d23ffb2ed7bd88e has 589 records
# Vessel 008aeeb68638c8e47842937ff56ba2b0671b368e96a8bd089f971bbf6ac54ccf has 721 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 785 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 344 records
# Vessel 0086b93a1666c0aa2876c335227a87b4e7e046a865502e712d23ffb2ed7bd88e has 301 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 755 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 28 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 65 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 229 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 458 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 38 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 278 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 533 records
# Vessel 019de1f551f4c92185ff870bf1ce15cb35eb318fac036e7caa5f0922694f4174 has 1 records
# Vessel 025dc2bc6e81fdd02b3deeb1e98ad62fce09c26abe98a01b661a997a1e67f40e has 1830 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 279 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 65 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 229 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 301 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 277 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 229 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 267 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 331 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 118 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 141 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 223 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 653 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 205 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 521 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 107 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 886 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 274 records
# Vessel 009624aaad81ceaa6d929f8692a47d962f5a0f98b5ef5df8b65adfd333652d33 has 189 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 521 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 107 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 888 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 271 records
# Vessel 009624aaad81ceaa6d929f8692a47d962f5a0f98b5ef5df8b65adfd333652d33 has 114 records
# Vessel 0103a5d407512ece89dc2dbef3ac6bd1e89aca8cc37f66cc8b79ccab4a701f88 has 1 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 18 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 633 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 308 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 532 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 506 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 278 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 908 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 232 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 641 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 220 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 5 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 633 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 308 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 408 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 630 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 475 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 444 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 89 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 358 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 17 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 634 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 442 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 358 records
# Vessel 0103a5d407512ece89dc2dbef3ac6bd1e89aca8cc37f66cc8b79ccab4a701f88 has 1 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 651 records
# Vessel 010c4a403aff4cee406b08c26a63bb30fb75a1cc4a019e3fe88e22243a98f71f has 6822 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 180 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1135 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 1295 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 653 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 43 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 732 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 687 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 184 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 44 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2390 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 442 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 102 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 742 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 40 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 588 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 774 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 58 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 865 records
# Vessel 02b6accae407908d9470f82f9b6e761a8f4a26a8bd74b20511abef7a03b67eb7 has 814 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 875 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 440 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 342 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 481 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 480 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 1292 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 656 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 40 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 18 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 705 records
# Vessel 01e13e30d70a8516f91bca15d881d6d66d9cdee472bb685d2ca78d541c3eaf0b has 1047 records
# Vessel 019de1f551f4c92185ff870bf1ce15cb35eb318fac036e7caa5f0922694f4174 has 17 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 270 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 650 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 195 records
# Vessel 025dc2bc6e81fdd02b3deeb1e98ad62fce09c26abe98a01b661a997a1e67f40e has 3459 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 834 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 429 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 20 records
# Vessel 019de1f551f4c92185ff870bf1ce15cb35eb318fac036e7caa5f0922694f4174 has 17 records
# Vessel 030313f06e3b7b1fa45ec48e4f7cfe91f3a075ac2758e02dd27d0e6ec72ff3c5 has 30 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 601 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 219 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 171 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 372 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 221 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 2 records
# Vessel 01e13e30d70a8516f91bca15d881d6d66d9cdee472bb685d2ca78d541c3eaf0b has 410 records
# Vessel 019de1f551f4c92185ff870bf1ce15cb35eb318fac036e7caa5f0922694f4174 has 17 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 591 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 199 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 661 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 172 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 157 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 10 records
# Vessel 00f6fa3011da44bb281a10dcab9571ea39838af67ed0251d19311d9c9373f295 has 32 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 326 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1121 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 456 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 330 records
# Vessel 018479af6a1d6edc9abef4446d55e5e2931bc5eaa2a5d2416a68b01bdde684df has 2 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 317 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 27 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 210 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 708 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 10 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 317 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 27 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 210 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 708 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 10 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 453 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 234 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 271 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 807 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 190 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 491 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 234 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1078 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 1066 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 491 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 219 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 473 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 5 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 889 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 767 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 294 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 530 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 224 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1061 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 288 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 242 records
# Vessel 0313405395417a034922d3a993a3978c2cb0336f352bc9c00f46e562bd4220de has 1278 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 159 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 734 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 453 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 675 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 291 records
# Vessel 0313405395417a034922d3a993a3978c2cb0336f352bc9c00f46e562bd4220de has 1099 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 75 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 75 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 493 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 281 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 3719 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 353 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 176 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 223 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 2265 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 2075 records
# Vessel 0248e8dd61ab12b7ce783182c3749c60af61aa999d58b9d443f1587fcf9aa3ee has 461 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 492 records
# Vessel 02cf59e39bb290e1df47bd36980f7d270da530fe73ead8fa831235b8c5776e59 has 1955 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 378 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 176 records
# Vessel 02cf59e39bb290e1df47bd36980f7d270da530fe73ead8fa831235b8c5776e59 has 1644 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 280 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 645 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 401 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 130 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 387 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1191 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 899 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 650 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 433 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 40 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 301 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1 records
# Vessel 038ecb5a5a4895593b333583ecfe0ab877bf1eed65be2e365c4c02eced52708a has 1545 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 941 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 377 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 15 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 248 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 15 records
# Vessel 029902c42673ff2c421294a0f8e6a3a4611e0fda68c4eb09b2d7d27dbed72dee has 330 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 1 records
# Vessel 032262d9ca0b219260aafb3165fb97ea462a2c3eebdaa4d9c00fc9bf732f26fd has 13 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 145 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 206 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 772 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 419 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 375 records
# Vessel 01c8d531d4f3dbf4d2ab71f0018d47aa0db2358fb532bf184bbfbfd2b73927b1 has 337 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 444 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 399 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 737 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 675 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 716 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 779 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 205 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 349 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 783 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 551 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 55 records
# Vessel 00c7725d1ff8ff36fc4091b1aef03261fb1a9e38b11f20d5604fb5607a94a4f2 has 151 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 320 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 548 records
# Vessel 0022d782dd964aa797f5f802a4abc6c5f06a1db8f5154033f302757e7dcfc0e8 has 14 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 349 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 320 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 113 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 320 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 320 records
# Vessel 00c7725d1ff8ff36fc4091b1aef03261fb1a9e38b11f20d5604fb5607a94a4f2 has 38 records
# Vessel 01a3fa7f6ad93a23ab50d87d4dcc1d27525c737d59a1bf692f5324505de9e1e8 has 5904 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 289 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 301 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 275 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 11 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 99 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 12 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 47 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 157 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 63 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 161 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 285 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 7 records
# Vessel 00aceee2b56d4833d9993cb44a0b7455679aea9407efea8aee4e9c3905ba729c has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 411 records
# Vessel 02227f34b54390f8ae2752a947f6c8aacf14ea1c13d37139317b0428bb452ea3 has 312 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 192 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 445 records
# Vessel 001f54b12baf3cb35ad144ae6bde3b7daa1500d49dd364f7e20f73903486459e has 99 records
# Vessel 00d2eaedeaee17499fef7b52e9967c36513d947aa83eb6c965eaa07955c9b1da has 115 records
# Vessel 000e14aa88e6df50cb046d573986def85340b63142b1e76a106aa88ad07afb06 has 400 records
# Vessel 000e14aa88e6df50cb046d573986def85340b63142b1e76a106aa88ad07afb06 has 377 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 484 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 451 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 90 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 65 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 467 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 461 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 81 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 594 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 108 records
# Vessel 0130914b4477656adcd46fc4d901b451cef40b4f9f56d99d534489ab1002e8ac has 496 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 1 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 1 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 15 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 48 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 3 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 31 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 76 records
# Vessel 002351f7584dcb3b6ab87557073727eadd310a71e141d35646da5a7e3c577ee0 has 66 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 151 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 145 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 41 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 28 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 41 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 49 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 33 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 29 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 46 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 4 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 8 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 77 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 103 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 142 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 33 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 27 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 19 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 20 records
# Vessel 003dde132a40628e14b1487edb3bcf25e094b850b0f30cc114bfab741411bc7a has 431 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 73 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 84 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 29 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 66 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 10 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 14 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 13 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 30 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 109 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 35 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 16 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 6 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 4 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 29 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 72 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 30 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 9 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 1 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 18 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 12 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 13 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 10 records
# Vessel 00710f6935ba79e2b7486842c1d88d4b28edfc1d1dbcbf5286f15755cdb2939a has 3 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 54 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 501 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 707 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 754 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 384 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 596 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 1305 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 674 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 628 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 720 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 681 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 762 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 749 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 734 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 739 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 672 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 739 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 810 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 62 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 177 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 806 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 562 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 115 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 192 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 71 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 298 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 397 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 339 records
# Vessel 00315accbfac1f7f34f17a84d0ea3d53a03ffe48078bdc7321877b4c6139b860 has 483 records
# Vessel 006338b72596eef85b7180edc1fc3b0750e4b378a8b2c8227ff0c720d7f20859 has 3 records

# %% [markdown]
# ----

# %%
CLEANED_WINDOWS = []
speed_idx = 2
course_idx = 3

# %%
for batch, vessel_ids in tqdm(loader, desc="Cleaning AIS data"):
    batch = batch.cpu()

    valid_mask = (
        ~torch.isnan(batch[:, :, 2]).any(dim=1) &
        ~torch.isnan(batch[:, :, 3]).any(dim=1)
    )

    valid_idx = valid_mask.nonzero(as_tuple=True)[0]

    if len(valid_idx) == 0:
        continue

    batch = batch[valid_idx]
    vessel_ids = [vessel_ids[i] for i in valid_idx.tolist()]

    # Clamp
    batch[:, :, 2] = batch[:, :, 2].clamp(0, 100)
    batch[:, :, 3] = batch[:, :, 3].clamp(0, 360)

    CLEANED_WINDOWS.append({
        "windows": batch,
        "vessel_ids": vessel_ids
    })
# Out:
# Cleaning AIS data: 283052it [07:46, 171.52it/s]

# %%
torch.save(CLEANED_WINDOWS, "cleaned_ais_windows.pt")
